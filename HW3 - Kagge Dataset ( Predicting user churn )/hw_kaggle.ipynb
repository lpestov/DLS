# %% [markdown]
# # Домашнее задание. Решение конкурса на kaggle.com
#
# Это домашнее задание посвящено полноценному решению задачи машинного обучения.

# %% [markdown]
# Есть две части этого домашнего задания:
#
# ### Отправить ваши предсказания в Stepik.
# За прохождение определенных порогов будут начисляться баллы. Эта часть оценивается из 5 баллов.
#
# 1) $1.00 \geqslant score \geqslant 0.84$ --- 5 баллов
#
# 2) $0.84 > score \geqslant 0.77$ --- 4 балла
#
# 3) $0.77 > score \geqslant 0.70$ --- 3 балла
#
# 4) $0.70 > score \geqslant 0.65$ --- 2 балла
#
# 5) $0.65 > score \geqslant 0.6$ --- 1 балл
#
# 6) $0.60 > score$ --- 0 баллов
#
# Для этого мы предварительно разделили данные в задании на две части.
# * `train.csv`. На этом наборе данных вам необходимо создать и обучить модель. Подробное описание файла есть в ноутбуке.
# * `test.csv`. В каждой строчке файла `test.csv` указаны признаки тестовых объектов. Предсказания для этого набора необходимо записать в файл submission.csv и сдать в соответствующий шаг на Stepik. Количество попыток ограничено 100 штук.
#
# Отправлять в Stepik вы будете файл с ответами `my_submission.csv`. В этом файле вам необходимо для каждого объекта из датасета предсказать вероятность класса 1. Мы подготовили для вас файл с примером посылки `submission.csv`. Ваш файл должен быть оформлен таким же образом. В ноутбуке есть пример оформления файла посылки. Для отправки файла с предсказаниями на Stepik есть отдельный шаг.
#
# ### Сделать полноценный отчет о вашей работе.
# Опишите, как вы обработали данные, какие модели попробовали и какие результаты получились (максимум 10 баллов). За каждую выполненную часть будет начислено определенное количество баллов. В этом пункте вам необходимо отправить файл в формате .ipynb на Stepik --- для этого в домашнем задании есть отдельный шаг. Этот пункт оценивается из 10 баллов.
#
# **Вторая часть будет проверяться в формате peer-review. Т.е. вашу посылку на Stepik будут проверять 3 других студента, и медианное значение их оценок будет выставлено. Чтобы получить баллы, вам также нужно будет проверить трех других учеников. Это станет доступно после того, как вы сдадите задание сами.**
#
# ### Контест на Kaggle
# Для вашего удобства мы подготовили [контест на Kaggle](https://www.kaggle.com/c/advanced-dls-spring-2021/). Тестирующая система на Kaggle выдает те же баллы, что и Stepik. Мы рекомендуем в качестве основной тестирующей системы использовать именно Kaggle, а затем сдать лучшую посылку на Stepik. Так вы привыкните работать с Kaggle.
#
# Проблема для российских пользователей Kaggle заключается в том, что подтверждение аккаунта по номеру телефона работает с перебоями или не работает вообще. Без подтвержденного номера телефона вы не сможете совершать посылки в kaggle. Если у вас возникла такая проблема, мы советуем следующие шаги:
# * Попробовать зарегистрировать аккаунт с аутентификацией через gmail. В таком случае, аккаунт должен работать без подтверждения номера телефона.
# * Если у вас есть не российский номер, используйте его для верификации аккаунта.
# * Если на номер телефона не приходит смс для верификации аккаунта, обратитесь в службу поддержки kaggle. Они с переменным успехом умеют подтверждать аккаунты вручную.
# * Если все же подтвердить аккаунт и получить доступ к сдаче заданий не удалось, используйте только сдачу в Stepik.
#
# ### Несколько замечаний по выполнению работы
# * Во всех пунктах указания это минимальный набор вещей, которые стоит сделать. Если вы можете сделать какой-то шаг лучше или добавить что-то свое --- дерзайте!
# * Пожалуйста, перед сдачей ноутбука убедитесь, что работа чистая и понятная. Это значительно облегчит проверку и повысит ваши ожидаемые баллы.
# * Если у вас будут проблемы с решением или хочется совета, то пишите в наш чат в телеграме.
#
#
# Данные: [train.csv](https://drive.google.com/file/d/1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K/view?usp=share_link),
# [test.csv](https://drive.google.com/file/d/1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r/view?usp=share_link), [submission.csv](https://drive.google.com/file/d/199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y/view?usp=share_link).
#
# Если ссылки на данные не работают, их можно скачать [на Kaggle](https://www.kaggle.com/competitions/advanced-dls-spring-2021/data).

# %% [markdown]
# # Как проверять?
#
# Ставьте полный балл, если выполнены все рекомендации или сделано что-то более интересное и сложное. За каждый отсустствующий пункт из рекомендации снижайте 1 балл.
#
# **Если решение верное, но не удовлетворяет вашим эстетическим предпочтениям, за это баллы снижать не нужно.**

# %% [markdown]
# # Метрика
#
# Перед решением любой задачи важно понимать, как будет оцениваться ваше решение. В данном случае мы используем стандартную для задачи классификации метрику ROC-AUC. Ее можно вычислить, используя только предсказанные вероятности и истинные классы без конкретного порога классификации + она раотает даже если классы в данных сильно несбалансированны (примеров одного класса в десятки раз больше примеров длугого). Именно поэтому она очень удобна для соревнований.
#
# Посчитать ее легко:

# %%
from IPython.core.pylabtools import figsize
from pandas import value_counts
from scipy.stats import alpha
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score

y_true = [
    0,
    1,
    1,
    0,
    1
]

y_predictions = [
    0.1,
    0.9,
    0.4,
    0.6,
    0.61
]

roc_auc_score(y_true, y_predictions)
# Out:
# 0.8333333333333333

# %% [markdown]
# # Первая часть. Исследование

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Загрузка данных (2 балла)
#
# 1) Посмотрите на случайные строчки.
#
# 2) Посмотрите, есть ли в датасете незаполненные значения (nan'ы) с помощью data.isna() или data.info() и, если нужно, замените их на что-то. Будет хорошо, если вы построите табличку с количеством nan в каждой колонке.

# %%
# !gdown 1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K  # train.csv
# !gdown 1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r  # test.csv
# !gdown 199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y  # submission.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K
# To: /home/leo/PycharmProjects/DLS/HW3 - Kagge Dataset ( Predicting user churn )/train.csv
# 100%|█████████████████████████████████████████| 664k/664k [00:01<00:00, 431kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r
# To: /home/leo/PycharmProjects/DLS/HW3 - Kagge Dataset ( Predicting user churn )/test.csv
# 100%|█████████████████████████████████████████| 218k/218k [00:01<00:00, 215kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y
# To: /home/leo/PycharmProjects/DLS/HW3 - Kagge Dataset ( Predicting user churn )/submission.csv
# 100%|███████████████████████████████████████| 14.7k/14.7k [00:00<00:00, 138kB/s]

# %%
data = pd.read_csv('train.csv')

# %%
# Для вашего удобства списки с именами разных колонок

# Числовые признаки
num_cols = [
    'ClientPeriod',
    'MonthlySpending',
    'TotalSpent'
]

# Категориальные признаки
cat_cols = [
    'Sex',
    'IsSeniorCitizen',
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasInternetService',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasContractPhone',
    'IsBillingPaperless',
    'PaymentMethod'
]

feature_cols = num_cols + cat_cols
target_col = 'Churn'

# %%
# Посмотрим на датасет
data
# Out:
#       ClientPeriod  MonthlySpending TotalSpent     Sex  IsSeniorCitizen  \
# 0               55            19.50    1026.35    Male                0
# 1               72            25.85     1872.2    Male                0
# 2                1            75.90       75.9    Male                0
# 3               32            79.30       2570  Female                1
# 4               60           115.25    6758.45  Female                0
# ...            ...              ...        ...     ...              ...
# 5277             3            30.40      82.15    Male                0
# 5278            50            44.45    2188.45    Male                0
# 5279             1            55.05      55.05    Male                0
# 5280            29            76.00    2215.25  Female                0
# 5281            19            75.90     1375.6  Female                0
#
#      HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# ...

# %%
# Переведем все числовые признаки в числовой тип
for col in num_cols:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
# Построим таблицу с количеством пропусков по каждой фиче и отсортируем
data.isna().sum().sort_values(ascending=False)
# Out:
# TotalSpent                  9
# ClientPeriod                0
# HasOnlineBackup             0
# PaymentMethod               0
# IsBillingPaperless          0
# HasContractPhone            0
# HasMovieSubscription        0
# HasOnlineTV                 0
# HasTechSupportAccess        0
# HasDeviceProtection         0
# HasOnlineSecurityService    0
# MonthlySpending             0
# HasInternetService          0
# HasMultiplePhoneNumbers     0
# HasPhoneService             0
# HasChild                    0
# HasPartner                  0
# IsSeniorCitizen             0
# Sex                         0
# Churn                       0
# dtype: int64

# %%
# Заменим средним в TotalSpent! Посмотрим также на случайные строки.
data['TotalSpent'] = data['TotalSpent'].fillna(data['TotalSpent'].mean())
data.sample(5)
# Out:
#       ClientPeriod  MonthlySpending  TotalSpent     Sex  IsSeniorCitizen  \
# 359             48           111.80     5443.65    Male                0
# 5057            51            59.30     3014.65    Male                0
# 1388            17            19.35      307.00  Female                0
# 2714            72            25.40     1797.10    Male                0
# 4231            57            53.75     3196.00    Male                0
#
#      HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 359         Yes      Yes             Yes                     Yes
# 5057        Yes      Yes              No        No phone service
# 1388        Yes       No             Yes                      No
# 2714        Yes       No             Yes                     Yes
# 4231         No       No              No        No phone service
#
#      HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# ...

# %%
# Проверим, что пропусков больше нет
data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Анализ данных (3 балла)
#
# 1) Для численных призанков постройте гистограмму (*plt.hist(...)*) или boxplot (*plt.boxplot(...)*). Для категориальных посчитайте количество каждого значения для каждого признака. Для каждой колонки надо сделать *data.value_counts()* и построить bar диаграммы *plt.bar(...)* или круговые диаграммы *plt.pie(...)* (хорошо, если вы сможете это сделать на одном графике с помощью *plt.subplots(...)*).
#
# 2) Посмотрите на распределение целевой переменной и скажите, являются ли классы несбалансированными.
#
# 3) (Если будет желание) Поиграйте с разными библиотеками для визуализации - *sns*, *pandas_visual_analysis*, etc.
#
# Второй пункт очень важен, потому что существуют задачи классификации с несбалансированными классами. Например, это может значить, что в датасете намного больше примеров 0 класса. В таких случаях нужно 1) не использовать accuracy как метрику 2) использовать методы борьбы с imbalanced dataset (обычно если датасет сильно несбалансирован, т.е. класса 1 в 20 раз меньше класса 0).

# %%
# Построим гистограммы для численных признаков (Их всего 3)
fig, axs = plt.subplots(1, len(num_cols), figsize=(15, 5))

# Можно сделать цикл, но так будет нагляднее
axs[0].hist(data[num_cols[0]], bins=20, color='blue', edgecolor='black', alpha=0.7)
axs[0].set_title('ClientPeriod')
axs[0].set_xlabel('ClientPeriod')
axs[0].set_ylabel('Frequency')

axs[1].hist(data[num_cols[1]], bins=20, color='green', edgecolor='black', alpha=0.7)
axs[1].set_title('MonthlySpending')
axs[1].set_xlabel('MonthlySpending')
axs[1].set_ylabel('Frequency')

axs[2].hist(data[num_cols[2]], bins=20, color='red', edgecolor='black', alpha=0.7)
axs[2].set_title('TotalSpent')
axs[2].set_xlabel('TotalSpent')
axs[2].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Мультимодальное распределение - ClientPeriod
# Правосторонне асимметричное распределение - MonthlySpending
# Правосторонне асимметричное распределение с длинным хвостом - TotalSpent

# %% [markdown]
# (Дополнительно) Если вы нашли какие-то ошибки в данных или выбросы, то можете их убрать. Тут можно поэксперементировать с обработкой данных как угодно, но не за баллы.

# %%
# Теперь поработаем с категориальными признаками и посчитаем количество каждого значения для каждого признака
for col in cat_cols:
    print(f'Value counts for {col}:')
    print(data[col].value_counts())
    print('\n')
# Out:
# Value counts for Sex:
# Sex
# Male      2655
# Female    2627
# Name: count, dtype: int64
#
#
# Value counts for IsSeniorCitizen:
# IsSeniorCitizen
# 0    4440
# 1     842
# Name: count, dtype: int64
#
#
# Value counts for HasPartner:
# HasPartner
# No     2705
# Yes    2577
# Name: count, dtype: int64
#
#
# Value counts for HasChild:
# HasChild
# No     3676
# Yes    1606
# Name: count, dtype: int64
#
#
# Value counts for HasPhoneService:
# HasPhoneService
# Yes    4761
# No      521
# Name: count, dtype: int64
#
#
# Value counts for HasMultiplePhoneNumbers:
# HasMultiplePhoneNumbers
# No                  2511
# Yes                 2250
# No phone service     521
# Name: count, dtype: int64
#
#
# Value counts for HasInternetService:
# HasInternetService
# Fiber optic    2341
# DSL            1800
# No             1141
# Name: count, dtype: int64
#
#
# Value counts for HasOnlineSecurityService:
# HasOnlineSecurityService
# No                     2612
# Yes                    1529
# ...

# %%
# Построим графики для категориальных признаков
fig, axs = plt.subplots(len(cat_cols), 2, figsize=(16, len(cat_cols) * 4))

# Дабы не плодить код, воспользуемся циклом
for i, col in enumerate(cat_cols):
    value_counts = data[col].value_counts()

    # Столбчатая диаграмма
    axs[i, 0].bar(value_counts.index, value_counts.values, color=['blue', 'green', 'red', 'orange'], alpha=0.8)
    axs[i, 0].set_title(f'Bar plot of {col}')
    axs[i, 0].set_xlabel(col)
    axs[i, 0].set_ylabel('Count')

    # Круговая диаграмма
    axs[i, 1].pie(value_counts.values, labels=value_counts.index, autopct='%1.1f%%',
                  colors=['#66b3ff', '#99ff99', '#ffcc99', '#ff6666'])
    axs[i, 1].set_title(f'Pie chart of {col}')

plt.tight_layout()
plt.show()

# %%
# Вполне себе стандартные графики, пока трудно сделать какие-то выводы

# %%
# Посмотрим на распределение целевой переменной
target_counts = data[target_col].value_counts()

colors = ['#1f77b4', '#ff7f0e']
labels = ['No Churn', 'Churn']

plt.figure(figsize=(8, 6))
plt.bar(target_counts.index, target_counts.values, color=colors)
plt.ylabel('Count', fontsize=12)
plt.title('Distribution of Target Variable (Churn)', fontsize=14)

for i, value in enumerate(target_counts.values):
    plt.text(i, value + 50, str(value), ha='center', fontsize=12)

plt.xticks([0, 1], labels, fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Есть дисбаланс классов, но не сильный

# %%
import seaborn as sns

# %%
# Посмотрим на корреляцию признаков с целевой переменной

# Вычисляем корреляцию Пирсона для числовых признаков с целевой переменной
correlation = data[num_cols + [target_col]].corr()[target_col].sort_values(ascending=False)

plt.figure(figsize=(8, 6))
sns.barplot(x=correlation.values, y=correlation.index, palette='coolwarm', hue=correlation.index, legend=False)

plt.title('Correlation of Features with Target Variable (Churn)', fontsize=16)
plt.xlabel('Correlation Coefficient', fontsize=12)
plt.ylabel('Features', fontsize=12)

# Отображаем значения корреляций на графике
for i, value in enumerate(correlation.values):
    plt.text(value + 0.01, i, f'{value:.2f}', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Корреляция числовых признаков с целевой переменной невысокая, но по небольшой отрицательной корреляции ClientPeriod можем сделать вывод, что чем дольше клиент остаётся с компанией, тем меньше вероятность, что он уйдёт.

# %% [markdown]
# ## Применение линейных моделей (3 балла)
#
# 1) Обработайте данные для того, чтобы к ним можно было применить LogisticRegression. Т.е. отнормируйте числовые признаки, а категориальные закодируйте с помощью one-hot-encoding'а.
#
# 2) С помощью кроссвалидации или разделения на train/valid выборку протестируйте разные значения гиперпараметра C и выберите лучший (можно тестировать С=100, 10, 1, 0.1, 0.01, 0.001) по метрике ROC-AUC.
#
# Если вы разделяете на train/valid, то используйте LogisticRegressionCV. Он сам при вызове .fit() подберет параметр С. (не забудьте передать scroing='roc_auc', чтобы при кроссвалидации сравнивались значения этой метрики, и refit=True, чтобы при потом модель обучилась на всем датасете с лучшим параметром C).
#
#
# (более сложный вариант) Если вы будете использовать кроссвалидацию, то преобразования данных и LogisticRegression нужно соединить в один Pipeline с помощью make_pipeline, как это делалось во втором семинаре. Потом pipeline надо передать в GridSearchCV. Для one-hot-encoding'a можно испльзовать комбинацию LabelEncoder + OneHotEncoder (сначала превращаем строчки в числа, а потом числа првращаем в one-hot вектора.)

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
# Разделим данные на признаки (X) и целевую переменную (y)
X = data[feature_cols]
y = data[target_col]

# Сделаем пайплан по обработке данных
numeric_transformer = make_pipeline(SimpleImputer(strategy='mean'), StandardScaler())
categorical_transformer = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder(handle_unknown='ignore'))

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_cols),
        ('cat', categorical_transformer, cat_cols)
    ]
)

# Создание итогового пайплайна
pipeline = make_pipeline(preprocessor, LogisticRegression(max_iter=2000))

# Параметры для GridSearchCV
param_grid = {
    'logisticregression__C': [100, 10, 1, 0.1, 0.01, 0.001]
    # Параметр C отвечает за степень регуляризации, C = 1/alpha - чем больше С, тем меньше модель ограничивает веса
}

# Так как классы целевой переменной не сбалансированы, то тупо делить на 5 блоков опасно, для того чтобы соблюдался баланс классов в каждом k фолде будем использовать стратификацию
cv = StratifiedKFold(n_splits=5)

# Создадим GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=cv, scoring='roc_auc', n_jobs=-1)

# Разделим данные на train и test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

grid_search.fit(X_train, y_train)

# Лучший результат и параметры
print(f"Лучшее значение гиперпараметра C: {grid_search.best_params_}")
print(f"Лучший ROC-AUC на кроссвалидации: {grid_search.best_score_:.4f}")

# Оценка на тестовой выборке
y_pred_proba = grid_search.best_estimator_.predict_proba(X_test)[:, 1]  # нас интересует вероятность класса 1
roc_auc_test = roc_auc_score(y_test, y_pred_proba)

print(f"ROC-AUC на тестовой выборке: {roc_auc_test:.4f}")
# Out:
# Лучшее значение гиперпараметра C: {'logisticregression__C': 10}
# Лучший ROC-AUC на кроссвалидации: 0.8452
# ROC-AUC на тестовой выборке: 0.8385

# %% [markdown]
# Выпишите какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ## Применение градиентного бустинга (2 балла)
#
# Если вы хотите получить баллы за точный ответ, то стоит попробовать градиентный бустинг. Часто градиентный бустинг с параметрами по умолчанию даст вам 80% результата за 0% усилий.
#
# Мы будем использовать catboost, поэтому нам не надо кодировать категориальные признаки. Catboost сделает это сам (в .fit() надо передать cat_features=cat_cols). А численные признаки нормировать для моделей, основанных на деревьях не нужно.
#
# 1) Разделите выборку на train/valid. Протестируйте catboost cо стандартными параметрами.
#
# 2) Протестируйте разные занчения параметров количества деревьев и learning_rate'а и выберите лучшую по метрике ROC-AUC комбинацию.
#
# (Дополнительно) Есть некоторые сложности с тем, чтобы использовать CatBoostClassifier вместе с GridSearchCV, поэтому мы не просим использовать кроссвалидацию. Но можете попробовать)

# %%
from catboost import CatBoostClassifier

# %%
# Разделим данные на train и valid (для catboost не нужно кодировать категориальные признаки)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)

# Инициализация модели CatBoost с параметрами по умолчанию (verbose=False уберет спам из консоли)
model = CatBoostClassifier(cat_features=cat_cols, verbose=False)

# Обучение модели
model.fit(X_train, y_train)

# Предсказание вероятностей на валидационном наборе
y_pred_proba = model.predict_proba(X_valid)[:, 1]

# Оценка метрики ROC-AUC
roc_auc = roc_auc_score(y_valid, y_pred_proba)
print(f"ROC-AUC с параметрами по умолчанию: {roc_auc:.4f}")
# Out:
# ROC-AUC с параметрами по умолчанию: 0.8513

# %%
# Подберем гиперпараметры
from itertools import product

n_trees = [100, 200, 500, 1000, 2000]  # Количество деревьев
learning_rates = [0.001, 0.01, 0.05, 0.1]  # Скорость обучения

best_roc_auc = 0
best_params = {}

# Перебор комбинаций параметров (не используем GridSearchCV, так как он плохо работает с CatBoost)
for n_tree, lr in product(n_trees, learning_rates):
    model = CatBoostClassifier(
        iterations=n_tree,
        learning_rate=lr,
        cat_features=cat_cols,
        verbose=False
    )

    model.fit(X_train, y_train)

    y_pred_proba = model.predict_proba(X_valid)[:, 1]

    roc_auc = roc_auc_score(y_valid, y_pred_proba)

    # Если метрика лучше текущей, сохраняем параметры
    if roc_auc > best_roc_auc:
        best_roc_auc = roc_auc
        best_params = {'iterations': n_tree, 'learning_rate': lr}

    print(f"n_tree: {n_tree}, learning_rate: {lr} => ROC-AUC: {roc_auc:.4f}")

# Вывод лучших параметров
print(f"\nЛучшие параметры: {best_params}")
print(f"Лучший ROC-AUC: {best_roc_auc:.4f}")
# Out:
# n_tree: 100, learning_rate: 0.001 => ROC-AUC: 0.8202
# n_tree: 100, learning_rate: 0.01 => ROC-AUC: 0.8357
# n_tree: 100, learning_rate: 0.05 => ROC-AUC: 0.8574
# n_tree: 100, learning_rate: 0.1 => ROC-AUC: 0.8565
# n_tree: 200, learning_rate: 0.001 => ROC-AUC: 0.8483
# n_tree: 200, learning_rate: 0.01 => ROC-AUC: 0.8563
# n_tree: 200, learning_rate: 0.05 => ROC-AUC: 0.8527
# n_tree: 200, learning_rate: 0.1 => ROC-AUC: 0.8483
# n_tree: 500, learning_rate: 0.001 => ROC-AUC: 0.8550
# n_tree: 500, learning_rate: 0.01 => ROC-AUC: 0.8568
# n_tree: 500, learning_rate: 0.05 => ROC-AUC: 0.8450
# n_tree: 500, learning_rate: 0.1 => ROC-AUC: 0.8406
# n_tree: 1000, learning_rate: 0.001 => ROC-AUC: 0.8549
# n_tree: 1000, learning_rate: 0.01 => ROC-AUC: 0.8554
# n_tree: 1000, learning_rate: 0.05 => ROC-AUC: 0.8380
# n_tree: 1000, learning_rate: 0.1 => ROC-AUC: 0.8355
# n_tree: 2000, learning_rate: 0.001 => ROC-AUC: 0.8544
# n_tree: 2000, learning_rate: 0.01 => ROC-AUC: 0.8523
# ...

# %% [markdown]
# Выпишите, какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ВАШ ОТВЕТ

# %% [markdown]
# # Предсказания

# %%
# Сохранение лучшей модели
best_model = CatBoostClassifier(iterations=best_params['iterations'], learning_rate=best_params['learning_rate'],
                                cat_features=cat_cols, verbose=False)

# %%
X_test = pd.read_csv('test.csv')
submission = pd.read_csv('submission.csv')

# %%
# Обработка тестовых данных
for col in num_cols:
    X_test[col] = pd.to_numeric(X_test[col], errors='coerce')

# %%
# Проверим пропуски
data.isna().sum().sort_values(ascending=False)
# Out:
# ClientPeriod                0
# MonthlySpending             0
# PaymentMethod               0
# IsBillingPaperless          0
# HasContractPhone            0
# HasMovieSubscription        0
# HasOnlineTV                 0
# HasTechSupportAccess        0
# HasDeviceProtection         0
# HasOnlineBackup             0
# HasOnlineSecurityService    0
# HasInternetService          0
# HasMultiplePhoneNumbers     0
# HasPhoneService             0
# HasChild                    0
# HasPartner                  0
# IsSeniorCitizen             0
# Sex                         0
# TotalSpent                  0
# Churn                       0
# dtype: int64

# %%
# Обучим модель на тестовых данных
best_model.fit(X, y)

# %%
# Сделаем предсказания  
submission['Churn'] = best_model.predict_proba(X_test)[:, 1]
submission.to_csv('my_submission.csv', index=False)
